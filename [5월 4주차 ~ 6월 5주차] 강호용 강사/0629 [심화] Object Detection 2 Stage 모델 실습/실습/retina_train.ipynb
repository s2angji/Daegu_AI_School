# %%
# !ls
# Out:
# custom_data.py	data_call.py  data_split.py  drive  sample_data

# %%
# !python /content/data_call.py --data FaceMaskDetection
# Out:
# Face Mask Detection.zip download complete
# File Name                                             Modified             Size
# annotations/maksssksksss0.xml                  2020-05-22 07:18:56         1252
# annotations/maksssksksss1.xml                  2020-05-22 07:18:56         3263
# annotations/maksssksksss10.xml                 2020-05-22 07:18:56          570
# annotations/maksssksksss100.xml                2020-05-22 07:18:56         1245
# annotations/maksssksksss101.xml                2020-05-22 07:18:56          571
# annotations/maksssksksss102.xml                2020-05-22 07:18:56          571
# annotations/maksssksksss103.xml                2020-05-22 07:18:56         1584
# annotations/maksssksksss104.xml                2020-05-22 07:18:56         2950
# annotations/maksssksksss105.xml                2020-05-22 07:18:56         3268
# annotations/maksssksksss106.xml                2020-05-22 07:18:56          571
# ...

# %%
# !python /content/data_split.py
# Out:
# 853
# 853
# img info  maksssksksss851.png
# img info  maksssksksss226.png
# img info  maksssksksss588.png
# img info  maksssksksss398.png
# img info  maksssksksss528.png
# img info  maksssksksss458.png
# img info  maksssksksss159.png
# img info  maksssksksss484.png
# img info  maksssksksss487.png
# img info  maksssksksss598.png
# img info  maksssksksss612.png
# img info  maksssksksss127.png
# img info  maksssksksss56.png
# img info  maksssksksss90.png
# img info  maksssksksss53.png
# img info  maksssksksss753.png
# img info  maksssksksss508.png
# img info  maksssksksss281.png
# img info  maksssksksss349.png
# img info  maksssksksss843.png
# img info  maksssksksss556.png
# img info  maksssksksss182.png
# img info  maksssksksss511.png
# img info  maksssksksss577.png
# img info  maksssksksss257.png
# img info  maksssksksss332.png
# img info  maksssksksss378.png
# img info  maksssksksss449.png
# img info  maksssksksss685.png
# img info  maksssksksss763.png
# ...

# %% [markdown]
# ##개발자 도구 console 에서 다음 자바스크립트 실행, 런타임 끊김 방지
#
# - 주의) 개발자 도구 창 닫지 않기 !!
#
# >function ClickConnect() { console.log("Working"); document.querySelector("colab-connect-button").shadowRoot.getElementById('connect').click(); } setInterval(ClickConnect,1800000);

# %%
# !python /content/custom_data.py
# Out:
# /usr/local/lib/python3.7/dist-packages/torchvision/models/_utils.py:209: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and will be removed in 0.15, please use 'weights' instead.
#   f"The parameter '{pretrained_param}' is deprecated since 0.13 and will be removed in 0.15, "
# /usr/local/lib/python3.7/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and will be removed in 0.15. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# /usr/local/lib/python3.7/dist-packages/torchvision/models/_utils.py:209: UserWarning: The parameter 'pretrained_backbone' is deprecated since 0.13 and will be removed in 0.15, please use 'weights_backbone' instead.
#   f"The parameter '{pretrained_param}' is deprecated since 0.13 and will be removed in 0.15, "
# ...
